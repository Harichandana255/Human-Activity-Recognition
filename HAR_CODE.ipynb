# %% [markdown]
# # Importing the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
  
# %matplotlib inline

# %% [markdown]
# # Obtaining the Train Data

# %%
train=pd.read_csv(r'C:\Users\chandana\Desktop\CAPSTONE\DATASETS\train.csv')
train.shape
# Out:
# (7352, 563)

# %%
train.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# 1            -0.998245         -0.975300         -0.960322         -0.998807
# 2            -0.995380         -0.967187         -0.978944         -0.996520
# 3            -0.996091         -0.983403         -0.990675         -0.997099
# 4            -0.998139         -0.980817         -0.990482         -0.998321
# ...                ...               ...               ...               ...
# 7347         -0.195387          0.039905          0.077078         -0.282301
# 7348         -0.235309          0.004816          0.059280         -0.322552
# 7349         -0.218218         -0.103822          0.274533         -0.304515
# 7350         -0.219139         -0.111412          0.268893         -0.310487
# 7351         -0.269270         -0.087212          0.177404         -0.377404
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.983185         -0.923527         -0.934724  ...
# 1            -0.974914         -0.957686         -0.943068  ...
# 2            -0.963668         -0.977469         -0.938692  ...
# 3            -0.982750         -0.989302         -0.938692  ...
# 4            -0.979672         -0.990441         -0.942469  ...
# ...                ...               ...               ...  ...
# 7347          0.043616          0.060410          0.210795  ...
# 7348         -0.029456          0.080585          0.117440  ...
# 7349         -0.098913          0.332584          0.043999  ...
# 7350         -0.068200          0.319473          0.101702  ...
# 7351         -0.038678          0.229430          0.269013  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                           -0.710304                    -0.112754
# 1                           -0.861499                     0.053477
# 2                           -0.760104                    -0.118559
# 3                           -0.482845                    -0.036788
# 4                           -0.699205                     0.123320
# ...                               ...                          ...
# 7347                        -0.880324                    -0.190437
# 7348                        -0.680744                     0.064907
# 7349                        -0.304029                     0.052806
# 7350                        -0.344314                    -0.101360
# 7351                        -0.740738                    -0.280088
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                                 0.030400                         -0.464761
# 1                                -0.007435                         -0.732626
# 2                                 0.177899                          0.100699
# 3                                -0.012892                          0.640011
# 4                                 0.122542                          0.693578
# ...                                    ...                               ...
# 7347                              0.829718                          0.206972
# 7348                              0.875679                         -0.879033
# 7349                             -0.266724                          0.864404
# 7350                              0.700740                          0.936674
# 7351                             -0.007739                         -0.056088
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                -0.018446             -0.841247
# 1                                 0.703511             -0.844788
# 2                                 0.808529             -0.848933
# 3                                -0.485366             -0.848649
# 4                                -0.615971             -0.847865
# ...                                    ...                   ...
# 7347                             -0.425619             -0.791883
# 7348                              0.400219             -0.771840
# 7349                              0.701169             -0.779133
# 7350                             -0.589479             -0.785181
# 7351                             -0.616956             -0.783267
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 0                 0.179941             -0.058627        1          STANDING
# 1                 0.180289             -0.054317        1          STANDING
# 2                 0.180637             -0.049118        1          STANDING
# 3                 0.181935             -0.047663        1          STANDING
# 4                 0.185151             -0.043892        1          STANDING
# ...                    ...                   ...      ...               ...
# 7347              0.238604              0.049819       30  WALKING_UPSTAIRS
# 7348              0.252676              0.050053       30  WALKING_UPSTAIRS
# 7349              0.249145              0.040811       30  WALKING_UPSTAIRS
# 7350              0.246432              0.025339       30  WALKING_UPSTAIRS
# 7351              0.246809              0.036695       30  WALKING_UPSTAIRS
#
# [7352 rows x 563 columns]

# %%
train.describe().T.head()
# Out:
#                     count      mean       std       min       25%       50%  \
# tBodyAcc-mean()-X  7352.0  0.274488  0.070261 -1.000000  0.262975  0.277193
# tBodyAcc-mean()-Y  7352.0 -0.017695  0.040811 -1.000000 -0.024863 -0.017219
# tBodyAcc-mean()-Z  7352.0 -0.109141  0.056635 -1.000000 -0.120993 -0.108676
# tBodyAcc-std()-X   7352.0 -0.605438  0.448734 -1.000000 -0.992754 -0.946196
# tBodyAcc-std()-Y   7352.0 -0.510938  0.502645 -0.999873 -0.978129 -0.851897
#
#                         75%       max
# tBodyAcc-mean()-X  0.288461  1.000000
# tBodyAcc-mean()-Y -0.010783  1.000000
# tBodyAcc-mean()-Z -0.097794  1.000000
# tBodyAcc-std()-X  -0.242813  1.000000
# tBodyAcc-std()-Y  -0.034231  0.916238

# %%
train[train['Activity'] == 'STANDING'].head(10)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
# 5           0.277199          -0.010098          -0.105137         -0.997335
# 6           0.279454          -0.019641          -0.110022         -0.996921
# 7           0.277432          -0.030488          -0.125360         -0.996559
# 8           0.277293          -0.021751          -0.120751         -0.997328
# 9           0.280586          -0.009960          -0.106065         -0.994803
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
# 5         -0.990487         -0.995420         -0.997627         -0.990218
# 6         -0.967186         -0.983118         -0.997003         -0.966097
# 7         -0.966728         -0.981585         -0.996485         -0.966313
# 8         -0.961245         -0.983672         -0.997596         -0.957236
# 9         -0.972758         -0.986244         -0.995405         -0.973663
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
# 5         -0.995549         -0.942469  ...                        -0.844619
# 6         -0.983116         -0.940987  ...                        -0.564430
# 7         -0.982982         -0.940987  ...                        -0.421715
# 8         -0.984379         -0.940598  ...                        -0.572995
# 9         -0.985642         -0.940028  ...                         0.140452
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
# 5                     0.082632                             -0.143439
# 6                    -0.212754                             -0.230622
# 7                    -0.020888                              0.593996
# 8                     0.012954                              0.080936
# 9                    -0.020590                             -0.127730
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
# 5                          0.275041                             -0.368224
# 6                          0.014637                             -0.189512
# 7                         -0.561871                              0.467383
# 8                         -0.234313                              0.117797
# 9                         -0.482871                             -0.070670
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
# 5             -0.849632              0.184823             -0.042126        1
# 6             -0.852150              0.182170             -0.043010        1
# 7             -0.851017              0.183779             -0.041976        1
# 8             -0.847971              0.188982             -0.037364        1
# 9             -0.848294              0.190310             -0.034417        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
# 5  STANDING
# 6  STANDING
# 7  STANDING
# 8  STANDING
# 9  STANDING
#
# [10 rows x 563 columns]

# %% [markdown]
# As a result, we can see that data have taken the count of STANDING from the train data.

# %%
train.dtypes.tail()
# Out:
# angle(X,gravityMean)    float64
# angle(Y,gravityMean)    float64
# angle(Z,gravityMean)    float64
# subject                   int64
# Activity                 object
# dtype: object

# %% [markdown]
# They have the same data types. That is, primarily floats and one object feature. Let's see what the object feature is and extract it from the rest.

# %% [markdown]
# # Obtaining the test data

# %%
test=pd.read_csv(r'C:\Users\chandana\Desktop\CAPSTONE\DATASETS\test.csv')
test.shape
# Out:
# (2947, 563)

# %%
test.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 12.7+ MB

# %%
test.describe().T.head()
# Out:
#                     count      mean       std       min       25%       50%  \
# tBodyAcc-mean()-X  2947.0  0.273996  0.060570 -0.592004  0.262075  0.277113
# tBodyAcc-mean()-Y  2947.0 -0.017863  0.025745 -0.362884 -0.024961 -0.016967
# tBodyAcc-mean()-Z  2947.0 -0.108386  0.042747 -0.576184 -0.121162 -0.108458
# tBodyAcc-std()-X   2947.0 -0.613635  0.412597 -0.999606 -0.990914 -0.931214
# tBodyAcc-std()-Y   2947.0 -0.508330  0.494269 -1.000000 -0.973664 -0.790972
#
#                         75%       max
# tBodyAcc-mean()-X  0.288097  0.671887
# tBodyAcc-mean()-Y -0.010143  0.246106
# tBodyAcc-mean()-Z -0.097123  0.494114
# tBodyAcc-std()-X  -0.267395  0.465299
# tBodyAcc-std()-Y  -0.105919  1.000000

# %%
test.describe().transpose()
# Out:
#                                        count       mean       std       min  \
# tBodyAcc-mean()-X                     2947.0   0.273996  0.060570 -0.592004
# tBodyAcc-mean()-Y                     2947.0  -0.017863  0.025745 -0.362884
# tBodyAcc-mean()-Z                     2947.0  -0.108386  0.042747 -0.576184
# tBodyAcc-std()-X                      2947.0  -0.613635  0.412597 -0.999606
# tBodyAcc-std()-Y                      2947.0  -0.508330  0.494269 -1.000000
# ...                                      ...        ...       ...       ...
# angle(tBodyGyroJerkMean,gravityMean)  2947.0  -0.017298  0.501311 -0.991096
# angle(X,gravityMean)                  2947.0  -0.513923  0.509205 -0.984195
# angle(Y,gravityMean)                  2947.0   0.074886  0.324300 -0.913704
# angle(Z,gravityMean)                  2947.0  -0.048720  0.241467 -0.949228
# subject                               2947.0  12.986427  6.950984  2.000000
#
#                                            25%        50%        75%  \
# tBodyAcc-mean()-X                     0.262075   0.277113   0.288097
# tBodyAcc-mean()-Y                    -0.024961  -0.016967  -0.010143
# tBodyAcc-mean()-Z                    -0.121162  -0.108458  -0.097123
# tBodyAcc-std()-X                     -0.990914  -0.931214  -0.267395
# tBodyAcc-std()-Y                     -0.973664  -0.790972  -0.105919
# ...                                        ...        ...        ...
# angle(tBodyGyroJerkMean,gravityMean) -0.428375  -0.026726   0.394387
# angle(X,gravityMean)                 -0.829722  -0.729648  -0.545939
# angle(Y,gravityMean)                  0.022140   0.181563   0.260252
# angle(Z,gravityMean)                 -0.098485  -0.010671   0.092373
# subject                               9.000000  12.000000  18.000000
#
#                                             max
# tBodyAcc-mean()-X                      0.671887
# tBodyAcc-mean()-Y                      0.246106
# tBodyAcc-mean()-Z                      0.494114
# tBodyAcc-std()-X                       0.465299
# tBodyAcc-std()-Y                       1.000000
# ...                                         ...
# angle(tBodyGyroJerkMean,gravityMean)   1.000000
# angle(X,gravityMean)                   0.833180
# angle(Y,gravityMean)                   1.000000
# angle(Z,gravityMean)                   0.973113
# subject                               24.000000
#
# [562 rows x 8 columns]

# %%
test.dtypes.tail()
# Out:
# angle(X,gravityMean)    float64
# angle(Y,gravityMean)    float64
# angle(Z,gravityMean)    float64
# subject                   int64
# Activity                 object
# dtype: object

# %% [markdown]
# They have the same data types. That is, primarily floats and one object feature. Let's see what the object feature is and extract it from the rest.

# %% [markdown]
# # Changing Feature Name

# %% [markdown]
# We can see some () 'bracket' among the feature's name. We will eliminate all specific brackets quickly. So it's easier for us to type correctly next.

# %%
columns = train.columns
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %% [markdown]
# We have decided which categorical variables you want to use in model

# %%
for col_name in train.columns:
    if train[col_name].dtypes == 'int64':
        unique_cat = len(train[col_name].unique())
        print("Feature '{col_name}' has {unique_cat} unique categories".format(col_name=col_name, unique_cat=unique_cat))
# Out:
# Feature 'subject' has 21 unique categories

# %% [markdown]
# Although "Activity" has a lot of unique categories, most categories only have a few observations

# %%
train['Activity'].value_counts().sort_values(ascending=False).head()
# Out:
# LAYING              1407
# STANDING            1374
# SITTING             1286
# WALKING             1226
# WALKING_UPSTAIRS    1073
# Name: Activity, dtype: int64

# %%
pd.crosstab(train.subject, train.Activity, margins = True).style.background_gradient(cmap='OrRd')
# Out:
# <style  type="text/css" >
# #T_c2651_row0_col0,#T_c2651_row0_col1,#T_c2651_row2_col0,#T_c2651_row2_col1,#T_c2651_row2_col6,#T_c2651_row4_col0,#T_c2651_row4_col1,#T_c2651_row4_col6,#T_c2651_row5_col0,#T_c2651_row5_col1,#T_c2651_row5_col3,#T_c2651_row5_col4,#T_c2651_row5_col5,#T_c2651_row5_col6,#T_c2651_row6_col2,#T_c2651_row7_col0,#T_c2651_row11_col4,#T_c2651_row11_col5,#T_c2651_row13_col3,#T_c2651_row13_col4,#T_c2651_row13_col5{
#             background-color:  #fff7ec;
#             color:  #000000;
#         }#T_c2651_row0_col2,#T_c2651_row1_col1,#T_c2651_row2_col2,#T_c2651_row2_col5,#T_c2651_row3_col0,#T_c2651_row3_col2,#T_c2651_row3_col6,#T_c2651_row4_col2,#T_c2651_row5_col2,#T_c2651_row6_col0,#T_c2651_row6_col1,#T_c2651_row6_col6,#T_c2651_row7_col6,#T_c2651_row8_col2,#T_c2651_row8_col3,#T_c2651_row8_col4,#T_c2651_row8_col5,#T_c2651_row8_col6,#T_c2651_row9_col3,#T_c2651_row10_col5,#T_c2651_row11_col3,#T_c2651_row12_col3,#T_c2651_row12_col5,#T_c2651_row13_col6,#T_c2651_row18_col3,#T_c2651_row19_col3{
#             background-color:  #fff7eb;
#             color:  #000000;
#         }#T_c2651_row0_col3{
#             background-color:  #fff2e1;
#             color:  #000000;
#         }#T_c2651_row0_col4,#T_c2651_row0_col5,#T_c2651_row1_col4,#T_c2651_row3_col4,#T_c2651_row6_col5,#T_c2651_row7_col5,#T_c2651_row8_col1,#T_c2651_row9_col0,#T_c2651_row9_col6,#T_c2651_row10_col0,#T_c2651_row10_col3,#T_c2651_row10_col6,#T_c2651_row13_col1,#T_c2651_row13_col2,#T_c2651_row14_col6,#T_c2651_row16_col4,#T_c2651_row16_col5,#T_c2651_row17_col6,#T_c2651_row18_col6,#T_c2651_row19_col0,#T_c2651_row19_col1,#T_c2651_row19_col2,#T_c2651_row19_col4,#T_c2651_row20_col0,#T_c2651_row20_col1,#T_c2651_row20_col6{
#             background-color:  #fff6e9;
#             color:  #000000;
#         }#T_c2651_row0_col6,#T_c2651_row1_col0,#T_c2651_row1_col2,#T_c2651_row1_col3,#T_c2651_row1_col6,#T_c2651_row2_col3,#T_c2651_row2_col4,#T_c2651_row3_col1,#T_c2651_row3_col3,#T_c2651_row3_col5,#T_c2651_row4_col3,#T_c2651_row4_col4,#T_c2651_row4_col5,#T_c2651_row6_col3,#T_c2651_row6_col4,#T_c2651_row7_col1,#T_c2651_row7_col2,#T_c2651_row7_col3,#T_c2651_row7_col4,#T_c2651_row9_col4,#T_c2651_row9_col5,#T_c2651_row10_col4,#T_c2651_row11_col6,#T_c2651_row12_col4,#T_c2651_row14_col3,#T_c2651_row14_col5,#T_c2651_row16_col3,#T_c2651_row17_col3,#T_c2651_row17_col4,#T_c2651_row17_col5,#T_c2651_row18_col4,#T_c2651_row18_col5,#T_c2651_row19_col5,#T_c2651_row19_col6,#T_c2651_row20_col2{
#             background-color:  #fff6ea;
#             color:  #000000;
#         }#T_c2651_row1_col5,#T_c2651_row8_col0,#T_c2651_row10_col1,#T_c2651_row12_col6,#T_c2651_row13_col0,#T_c2651_row14_col0,#T_c2651_row14_col1,#T_c2651_row14_col2,#T_c2651_row14_col4,#T_c2651_row15_col0,#T_c2651_row15_col1,#T_c2651_row15_col6,#T_c2651_row16_col0,#T_c2651_row16_col6,#T_c2651_row17_col0,#T_c2651_row20_col3{
#             background-color:  #fff5e7;
#             color:  #000000;
#         }#T_c2651_row9_col1,#T_c2651_row9_col2,#T_c2651_row10_col2,#T_c2651_row11_col1,#T_c2651_row11_col2,#T_c2651_row15_col2,#T_c2651_row15_col4,#T_c2651_row16_col2,#T_c2651_row17_col1,#T_c2651_row18_col0,#T_c2651_row18_col1{
#             background-color:  #fff5e6;
#             color:  #000000;
#         }#T_c2651_row11_col0,#T_c2651_row15_col3,#T_c2651_row15_col5,#T_c2651_row17_col2,#T_c2651_row18_col2,#T_c2651_row20_col5{
#             background-color:  #fff4e5;
#             color:  #000000;
#         }#T_c2651_row12_col0,#T_c2651_row16_col1,#T_c2651_row20_col4{
#             background-color:  #fff4e4;
#             color:  #000000;
#         }#T_c2651_row12_col1,#T_c2651_row12_col2{
#             background-color:  #fff3e3;
#             color:  #000000;
#         }#T_c2651_row21_col0,#T_c2651_row21_col1,#T_c2651_row21_col2,#T_c2651_row21_col3,#T_c2651_row21_col4,#T_c2651_row21_col5,#T_c2651_row21_col6{
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }</style><table id="T_c2651_" ><thead>    <tr>        <th class="index_name level0" >Activity</th>        <th class="col_heading level0 col0" >LAYING</th>        <th class="col_heading level0 col1" >SITTING</th>        <th class="col_heading level0 col2" >STANDING</th>        <th class="col_heading level0 col3" >WALKING</th>        <th class="col_heading level0 col4" >WALKING_DOWNSTAIRS</th>        <th class="col_heading level0 col5" >WALKING_UPSTAIRS</th>        <th class="col_heading level0 col6" >All</th>    </tr>    <tr>        <th class="index_name level0" >subject</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2651_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_c2651_row0_col0" class="data row0 col0" >50</td>
#                         <td id="T_c2651_row0_col1" class="data row0 col1" >47</td>
#                         <td id="T_c2651_row0_col2" class="data row0 col2" >53</td>
#                         <td id="T_c2651_row0_col3" class="data row0 col3" >95</td>
#                         <td id="T_c2651_row0_col4" class="data row0 col4" >49</td>
#                         <td id="T_c2651_row0_col5" class="data row0 col5" >53</td>
#                         <td id="T_c2651_row0_col6" class="data row0 col6" >347</td>
#             </tr>
#             <tr>
#                         <th id="T_c2651_level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_c2651_row1_col0" class="data row1 col0" >62</td>
#                         <td id="T_c2651_row1_col1" class="data row1 col1" >52</td>
#                         <td id="T_c2651_row1_col2" class="data row1 col2" >61</td>
#                         <td id="T_c2651_row1_col3" class="data row1 col3" >58</td>
#                         <td id="T_c2651_row1_col4" class="data row1 col4" >49</td>
#                         <td id="T_c2651_row1_col5" class="data row1 col5" >59</td>
#                         <td id="T_c2651_row1_col6" class="data row1 col6" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_c2651_level0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_c2651_row2_col0" class="data row2 col0" >52</td>
#                         <td id="T_c2651_row2_col1" class="data row2 col1" >44</td>
#                         <td id="T_c2651_row2_col2" class="data row2 col2" >56</td>
#                         <td id="T_c2651_row2_col3" class="data row2 col3" >56</td>
#                         <td id="T_c2651_row2_col4" class="data row2 col4" >47</td>
#                         <td id="T_c2651_row2_col5" class="data row2 col5" >47</td>
#                         <td id="T_c2651_row2_col6" class="data row2 col6" >302</td>
#             </tr>
#             <tr>
#                         <th id="T_c2651_level0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_c2651_row3_col0" class="data row3 col0" >57</td>
#                         <td id="T_c2651_row3_col1" class="data row3 col1" >55</td>
#                         <td id="T_c2651_row3_col2" class="data row3 col2" >57</td>
#                         <td id="T_c2651_row3_col3" class="data row3 col3" >57</td>
#                         <td id="T_c2651_row3_col4" class="data row3 col4" >48</td>
#                         <td id="T_c2651_row3_col5" class="data row3 col5" >51</td>
#                         <td id="T_c2651_row3_col6" class="data row3 col6" >325</td>
#             </tr>
#             <tr>
#                         <th id="T_c2651_level0_row4" class="row_heading level0 row4" >7</th>
#                         <td id="T_c2651_row4_col0" class="data row4 col0" >52</td>
#                         <td id="T_c2651_row4_col1" class="data row4 col1" >48</td>
#                         <td id="T_c2651_row4_col2" class="data row4 col2" >53</td>
#                         <td id="T_c2651_row4_col3" class="data

# %% [markdown]
# # DATA ANALYSIS

# %%
import seaborn as sns
from matplotlib import gridspec
import matplotlib.cm as cm

# %% [markdown]
# % of Different categories
#
#
# There are five different activities, i.e., 'Standing,' 'Sitting,' 'Laying,' 'Walking,' 'Walking_downstairs,' 'Walking_upstairs.'

# %%
with sns.axes_style('whitegrid'):
    label_freq = train['Activity'].value_counts() / len(train)
    print(label_freq)
# Out:
# LAYING                0.191376
# STANDING              0.186888
# SITTING               0.174918
# WALKING               0.166757
# WALKING_UPSTAIRS      0.145947
# WALKING_DOWNSTAIRS    0.134113
# Name: Activity, dtype: float64

# %%
with sns.axes_style('whitegrid'):
    fig = label_freq.sort_values(ascending=False).plot.bar(figsize=(10,5),
                                                           align='center',
                                                           color='indianred')
    fig.axhline(y=0.10, color='red')
    fig.set_ylabel('percentage of Activty within each category')
    fig.set_xlabel('Variable: Activity')
    fig.set_title('Identifying Categories')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Conclusion
#
#
# As the percentage is roughly equal, consequently, we can examine it to a balanced dataset.

# %%
with sns.axes_style('whitegrid'):
    train.groupby(['subject']).subject.count().plot(kind='barh',
                                      title='Plotting records by subject type', 
                                      figsize=(10,5),color='salmon',
                                      align='center')

# %% [markdown]
# Conclusion
#
#
# Subject ID 19 and 25 did a lot of different activities.

# %%
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(20,5))
    plt.title('No of Data subjects per Activity', fontsize=16)
    sns.lineplot(x="Activity", y="subject",data=train,palette="tab10", linewidth=2.5,drawstyle='default')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Conclusion
#
#
# In data show, Individual subjects perform an activity depending on their habits. We can recognize the underlying activity as quite challenging on their determine.

# %%
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(7,7))
    sns.boxplot(x='Activity',
            y='angleXgravityMean',
            data=train,
            palette="Set3",
            linewidth=2.5,
            dodge=False,
            showfliers=False,
            saturation=1)
    plt.axhline(y=-0.5, xmin=0.3, xmax=1,dashes=(5,5), c='g')
    plt.axhline(y=0.3, xmin=0.3, dashes=(5,5), c='m')
    plt.ylabel('Angle between X-axis and Gravity_mean')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Conclusion
#
#
# angleXgravityMean is < 0.0 then the Activities are either Standing or Sitting orWalking or WalkingDownstairs or WalkingUpstairs.
# angleXgravityMean is > 0.0 then the Activity is Laying .
# </i></p>

# %%
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(7,7))
    sns.boxplot(x='Activity', 
            y='tBodyAccMagmean',
            data=train, 
            palette="Set1",
            linewidth=2.5,
            dodge=False,
            showfliers=False,
            saturation=1)
    plt.ylabel('Acceleration Magnitude mean')
    plt.axhline(y=-0.9, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
    plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Conclusion
#
#
# -->tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# -->tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# -->tAccMean is > 0.0 then the Activity is WalkingDownstairs.
# -->We can classify 75% the Acitivity labels with some errors.

# %%
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(7,7))
    sns.barplot(x='Activity', y='tGravityAccsma',data=train,
            palette="Pastel2",
            linewidth=3)
    plt.ylabel('Gravity acceleration using Signal magnitude area')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Conclusion
#
#
# -->tGravityAccsma is < 0.0 then the Activities are either Standing or Sitting or Walking or WalkingDownstairs.
# -->tGravityAccsma is > 0.0 then the Activities are either Laying or WalkingUpstairs .

# %%
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(7,7))
    sns.barplot(x="Activity",
                y="tBodyAccarCoeffY1",
                data=train,
                palette="autumn")
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Conclusion
#
#
# -->tBodyAccarCoeffY1 is > 0.0 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# -->tBodyAccarCoeffY1 is < 0.0 then the Activities are either Laying or Standing or Sitting .

# %%
sns.catplot(x="subject", 
            y="tBodyAccMagmax",
            data=train, 
            kind="violin",
            height=10,
             palette="RdPu",
            aspect=3,
            hue_order= "Activity")
plt.show()

# %% [markdown]
# Conclusion
#
#
# We examined the train data to check the balance between the tBodyAccMagmax observations performed by the 30 subjects.

# %%
with sns.axes_style('whitegrid'):
    sns.catplot(x="subject", 
            y="fBodyBodyGyroMagmeanFreq",
            data=train, 
            kind="boxen",
             palette="winter",
            height=4,
            aspect=2.7,
            hue_order= "Activity")
    plt.show()

# %% [markdown]
# Conclusion
#
# We examined the train data to check the balance between the fBodyBodyGyroMagmeanFreq observations performed by the 30 subjects.

# %%
with sns.axes_style('darkgrid'):
    plt.figure(figsize=(14,10))
    plt.title('Activity as per the users')
    g = sns.countplot(x='subject',hue='Activity', 
                      data=train, palette = 'Spectral')

# %% [markdown]
# Conclusion
#
# As we can see, We have got the almost identical number of reading from all the subjects means there are no significant differences in reading, and then we should not worry about it. We have got almost the same number of reading from all the subjects.

# %%
with sns.axes_style('darkgrid'):
    fig = plt.figure(figsize=(35,25))
    ax1 = fig.add_subplot(221)
    ax1 = sns.stripplot(x='Activity', y='tBodyAccmaxX', data=train.loc[train['subject']==1], jitter=True)
    plt.xticks(rotation=90)
    ax2 = fig.add_subplot(222)
    ax2 = sns.stripplot(x='Activity', y='tBodyAccmaxY', data=train.loc[train['subject']==1], jitter=True)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Conclusion
#
# Passive activities fall mostly below the active ones. Therefore, it makes sense that maximum acceleration is higher during the walking exercises.

# %%
with sns.axes_style('darkgrid'):
    sub15 = train.loc[train['subject']==15]
    fig = plt.figure(figsize=(35,25))
    ax1 = fig.add_subplot(221)
    ax1 = sns.stripplot(x='Activity', y=sub15.iloc[:,0], data=sub15, jitter=True)
    ax2 = fig.add_subplot(222)
    ax2 = sns.stripplot(x='Activity', y=sub15.iloc[:,1], data=sub15, jitter=True)
    plt.show()

# %% [markdown]
# Conclusion
#
# We can now see the difference in the distribution between the active and passive activities with the walk-down activity (i.e., values between 0.5 and 0.8) distinct from all others, especially in the X-direction. On the other hand, the passive activities are indistinguishable and present no clear pattern in any direction (X, Y, Z).

# %%
with sns.axes_style('whitegrid'):
    features = ['tBodyAccJerksma','tBodyAccMagmad','tBodyGyroJerkMagiqr','Activity']
    train_subset = train[features]
    g = sns.pairplot(train_subset, hue='Activity',
                 palette='Paired',height=7,
                 aspect=1)
    g.map_offdiag(sns.scatterplot)
    plt.suptitle('Scatter-matrix for each input variable')
    g.add_legend()
    plt.xticks(rotation=45)

# %% [markdown]
# Conclusion
#
# Some pairs of Activities are correlated. We suggest a high correlation and a predictable relationship.

# %%
plt.figure(figsize=(30,20))
sns.heatmap(data=(train.corr()*train.corr()),cmap="BuPu",vmin=0.4)
plt.show()

# %% [markdown]
# Conclusion
#
# As we observe above, our data should contain multiple columns, and they are sensor arrangements. So they are not practicing the best data to visualize.

# %% [markdown]
# # Check the null values or not

# %%
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# 0                     -0.710304                 -0.112754
# 1                     -0.861499                  0.053477
# 2                     -0.760104                 -0.118559
# 3                     -0.482845                 -0.036788
# 4                     -0.699205                  0.123320
#
#    angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                          0.030400                      -0.464761
# 1                         -0.007435                      -0.732626
# 2                          0.177899                       0.100699
# 3                         -0.012892                       0.640011
# 4                          0.122542                       0.693578
#
#    angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                          -0.018446          -0.841247           0.179941
# 1                           0.703511          -0.844788           0.180289
# 2                           0.808529          -0.848933           0.180637
# 3                          -0.485366          -0.848649           0.181935
# 4                          -0.615971          -0.847865           0.185151
#
#    angleZgravityMean  subject  Activity
# 0          -0.058627        1  STANDING
# 1          -0.054317        1  STANDING
# 2          -0.049118        1  STANDING
# 3          -0.047663        1  STANDING
# 4          -0.043892        1  STANDING
#
# [5 rows x 563 columns]

# %% [markdown]
# As we observed, our train dataset has 7352 instances and 563 attributes.Instantly, let us examine the null values, see if we should have any.

# %%
print(train.isnull().sum())
if(any(list(train.isnull().sum())) !=0):
    print("--------------------------")
    print("We have null values")
else:
    print("--------------------------")
    print("We don't have null values")
# Out:
# tBodyAccmeanX        0
# tBodyAccmeanY        0
# tBodyAccmeanZ        0
# tBodyAccstdX         0
# tBodyAccstdY         0
#                     ..
# angleXgravityMean    0
# angleYgravityMean    0
# angleZgravityMean    0
# subject              0
# Activity             0
# Length: 563, dtype: int64
# --------------------------
# We don't have null values

# %%
plt.figure(figsize=(15,5)) 
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
def basic_details(train):
    b = pd.DataFrame()
    b['Missing value'] = train.isnull().sum()
    b['N unique value'] = train.nunique()
    b['dtype'] = train.dtypes
    return b
basic_details(train)
# Out:
#                    Missing value  N unique value    dtype
# tBodyAccmeanX                  0            7347  float64
# tBodyAccmeanY                  0            7352  float64
# tBodyAccmeanZ                  0            7349  float64
# tBodyAccstdX                   0            7349  float64
# tBodyAccstdY                   0            7351  float64
# ...                          ...             ...      ...
# angleXgravityMean              0            7352  float64
# angleYgravityMean              0            7352  float64
# angleZgravityMean              0            7352  float64
# subject                        0              21    int64
# Activity                       0               6   object
#
# [563 rows x 3 columns]

# %% [markdown]
# Conclusion
#
# We first look at the different activities produced and sensed by the trackers. There are six activities overall. We are so plotting these first.

# %%
test.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1       0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2       0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3       0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4       0.274833      -0.027848      -0.129527     -0.993852     -0.967445
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.667683     -0.952501     -0.925249     -0.674302     -0.894088  ...
# 1     -0.944958     -0.986799     -0.968401     -0.945823     -0.894088  ...
# 2     -0.962748     -0.994403     -0.970735     -0.963483     -0.939260  ...
# 3     -0.967091     -0.995274     -0.974471     -0.968897     -0.938610  ...
# 4     -0.978295     -0.994111     -0.965953     -0.977346     -0.938610  ...
#
#    fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# 0                     -0.705974                  0.006462
# 1                     -0.594944                 -0.083495
# 2                     -0.640736                 -0.034956
# 3                     -0.736124                 -0.017067
# 4                     -0.846595                 -0.002223
#
#    angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                          0.162920                      -0.825886
# 1                          0.017500                      -0.434375
# 2                          0.202302                       0.064103
# 3                          0.154438                       0.340134
# 4                         -0.040046                       0.736715
#
#    angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                           0.271151          -0.720009           0.276801
# 1                           0.920593          -0.698091           0.281343
# 2                           0.145068          -0.702771           0.280083
# 3                           0.296407          -0.698954           0.284114
# 4                          -0.118545          -0.692245           0.290722
#
#    angleZgravityMean  subject  Activity
# 0          -0.057978        2  STANDING
# 1          -0.083898        2  STANDING
# 2          -0.079346        2  STANDING
# 3          -0.077108        2  STANDING
# 4          -0.073857        2  STANDING
#
# [5 rows x 563 columns]

# %% [markdown]
# As we observed, our test dataset has 2947 instances and 563 attributes.

# %%
def basic_details(test):
    b = pd.DataFrame()
    b['Missing value'] = test.isnull().sum()
    b['N unique value'] = test.nunique()
    b['dtype'] = train.dtypes
    return b
basic_details(test)
# Out:
#                    Missing value  N unique value    dtype
# tBodyAccmeanX                  0            2947  float64
# tBodyAccmeanY                  0            2947  float64
# tBodyAccmeanZ                  0            2947  float64
# tBodyAccstdX                   0            2947  float64
# tBodyAccstdY                   0            2947  float64
# ...                          ...             ...      ...
# angleXgravityMean              0            2947  float64
# angleYgravityMean              0            2947  float64
# angleZgravityMean              0            2947  float64
# subject                        0               9    int64
# Activity                       0               6   object
#
# [563 rows x 3 columns]

# %% [markdown]
# Conclusion
#
# We first look at the different activities produced and sensed by the trackers. There are six activities overall. We are so plotting these first.

# %% [markdown]
# # Cardinality in categorical variables

# %%
with sns.axes_style('whitegrid'):
    train.nunique().plot.line(figsize=(15,6),color="tan")
    plt.ylabel('Number of unique categories')
    plt.xlabel('Variables')
    plt.title('Cardinality')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Conclusion
#
# The number of unique categories in a variable is called cardinality.

# %%
Acc = 0
Gyro = 0
other = 0

for value in train.columns:
    if "Acc" in str(value):
        Acc += 1
    elif "Gyro" in str(value):
        Gyro += 1
    else:
        other += 1

# %%
plt.figure(figsize=(10,5))
plt.bar(['Accelerometer', 'Gyroscope', 'Others'],[Acc,Gyro,other],color = ('orangered', 'khaki', 'limegreen'))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Conclusion
#
# Accelerometer aggregates the main features, followed by Gyroscope. Other unusual features are very few.

# %% [markdown]
# # Data Preprocessing

# %%
#LABELS
labels = { 'WALKING', 
          'WALKING_UPSTAIRS',
          'WALKING_DOWNSTAIRS',
          'SITTING',
          'STANDING',
          'LAYING'}

# %%
test_model_score = pd.DataFrame(columns = ("Model","Score"))

# %%
train_model_score = pd.DataFrame(columns = ("Model","Score"))

# %% [markdown]
# # Let's the model with our data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import preprocessing
from sklearn.preprocessing import scale
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # seperating class label from the dataset

# %%
Y_train = train.Activity.values
X_train = pd.DataFrame(train.drop(['Activity','subject'],axis=1)).values

Y_test = test.Activity.values
X_test = pd.DataFrame(test.drop(['Activity','subject'],axis=1)).values

print("Class labels striped off the dataset")
# Out:
# Class labels striped off the dataset

# %%
X_train, X_test,Y_train, Y_test = train_test_split(X_train, Y_train,
                                               test_size = 0.2, 
                                               random_state=42)

# %%
print('Training data size : ', X_train.shape)
print('Test data size : ', X_test.shape)
# Out:
# Training data size :  (5881, 561)
# Test data size :  (1471, 561)

# %%
print('Training model with {} dimensions.'.format(X_train.shape[1]))
print('\nTesting model with {} dimensions.'.format(X_test.shape[1]))
# Out:
# Training model with 561 dimensions.
#
# Testing model with 561 dimensions.

# %%
Training_to_original_ratio = round(X_train.shape[0]/(train.shape[0]), 2) * 100

Testing_to_original_ratio = round(X_test.shape[0]/(train.shape[0]), 2) * 100

print ('As shown below {}% of the data is for training and the rest {}% is for testing.'.format(Training_to_original_ratio, 
                                                                                               Testing_to_original_ratio))
list(zip(["Training set", "Testing set"],
   [Training_to_original_ratio, Testing_to_original_ratio]))
# Out:
# As shown below 80.0% of the data is for training and the rest 20.0% is for testing.
# [('Training set', 80.0), ('Testing set', 20.0)]

# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# Decision tree-based models use training data to derive rules that are used to predict an output.
#
# Depending on the values from the training data, the model forms a decision tree.

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dt = DecisionTreeClassifier(max_leaf_nodes=20, random_state=0,max_depth=20)
clf_dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=20, max_leaf_nodes=20, random_state=0)

# %%
y_pred = clf_dt.predict(X_test)
x_pred= clf_dt.predict(X_train)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_dtc_accuracy = accuracy_score(Y_test, y_pred)
print("Testing Accuracy using Decision Tree Classifier:",test_dtc_accuracy)
# Out:
# Testing Accuracy using Decision Tree Classifier: 0.9211420802175391

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 92% while accurately analyzing the predicted output list.
#
#
# Checking the model's training accuracy

# %%
train_dtc_accuracy = accuracy_score(Y_train, x_pred)
print("Testing Accuracy using Decision Tree Classifier:",train_dtc_accuracy)
# Out:
# Testing Accuracy using Decision Tree Classifier: 0.9360652950178541

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 94% while accurately analyzing the predicted output list.

# %%
print('Depth of the Decision Tree :', clf_dt.get_depth())
# Out:
# Depth of the Decision Tree : 8

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       280
#            SITTING       0.95      0.82      0.88       262
#           STANDING       0.85      0.95      0.90       276
#            WALKING       0.95      0.92      0.94       247
# WALKING_DOWNSTAIRS       0.95      0.89      0.92       206
#   WALKING_UPSTAIRS       0.84      0.94      0.89       200
#
#           accuracy                           0.92      1471
#          macro avg       0.92      0.92      0.92      1471
#       weighted avg       0.93      0.92      0.92      1471

# %%
from sklearn.metrics import plot_confusion_matrix
# Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8))
matrix = plot_confusion_matrix(clf_dt, X_test, Y_test,
                                 cmap='Greens',
                                 normalize='true',ax=ax)


plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':15} 
plt.title('Confusion matrix for Decision Tree ',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show(matrix)

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the Decision tree classifier, well-known exceptions properly include the classification of SITTING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS. Whereas LAYING, WALKING, and STANDING are seemed to fail us sometimes as well.

# %%
train_model_score=train_model_score.append(pd.DataFrame({'Model':["Decision Tree Classifier"],'Score':[train_dtc_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["Decision Tree Classifier"],'Score':[test_dtc_accuracy]}))

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X_train[:, :10])
scaler.transform(X_train[:, :10]).mean(axis=0)
# Out:
# array([ 9.73394314e-15, -1.06565175e-15,  4.85816492e-15, -1.73172893e-15,
#        -1.60396173e-15, -1.24455982e-15, -8.69489068e-16,  1.13837032e-15,
#        -5.28738760e-16, -4.85809885e-16])

# %%
X = scaler.fit_transform(X_train)
X.shape
# Out:
# (5881, 561)

# %%
my_useless_scaler = preprocessing.StandardScaler(with_mean=False,with_std=False)
transformed_sd = my_useless_scaler.fit_transform(X_train[:, :3]).std(axis=0)
original_sd = X_train[:, :3].std(axis=0)
np.array_equal(transformed_sd, original_sd)
# Out:
# True

# %% [markdown]
# Conclusion
#
# The possible motivation to properly use this scaling includes robustness to minimal standard deviations of features and preserving zero entries in sparse data.

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# In a logistic regression algorithm, instead of predicting the actual continuous value, we expect the probability of an outcome. To achieve data, a logistic function is applied to the outcome of the linear regression. The logistic process is also referred to as a sigmoid function. As a result, it outputs a value between 0 and 1.

# %%
parameters = {'C':np.arange(10,61,10),'penalty':['l2','l1']} 

lgr=LogisticRegression(penalty='l2',C=.01)
lgr_clf_rs = RandomizedSearchCV(lgr, param_distributions = parameters, cv = 5, random_state = 42)
lgr_clf_rs.fit(X_train, Y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(C=0.01),
#                    param_distributions={'C': array([10, 20, 30, 40, 50, 60]),
#                                         'penalty': ['l2', 'l1']},
#                    random_state=42)

# %% [markdown]
# Hyperparameters are essential as they manage the overall behaviour of a machine learning model. The ultimate aim is to find an optimal combination of hyperparameters that decreases a predefined loss function to give more reliable outcomes.
#
#
# Grid-search is practiced to obtain the optimal hyperparameters, resulting in the most ‘accurate’ predictions.
#
#
# L1 tends to shrink coefficients to zero from a practical standpoint, whereas L2 tends to shrink coefficients evenly. L1 is therefore helpful for feature selection, as we can drop any variables associated with coefficients that go to zero. L2, on the other hand, is valid when you have collinear/codependent features.

# %%
y_pred = lgr_clf_rs.predict(X_test)
x_pred = lgr_clf_rs.predict(X_train)

# %%
test_lgr_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using Logisitc Regression:", test_lgr_accuracy)
# Out:
# Testing Accuracy using Logisitc Regression: 0.9782460910944936

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 97.8% while accurately analyzing the predicted output list.
#
#
# Checking the model's training accuracy

# %%
# Checking the model's training accuracy
train_lgr_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using Logisitc Regression:", train_lgr_accuracy)
# Out:
# Training Accuracy using Logisitc Regression: 0.9916680836592416

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 99% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       280
#            SITTING       0.95      0.95      0.95       262
#           STANDING       0.95      0.95      0.95       276
#            WALKING       0.99      1.00      0.99       247
# WALKING_DOWNSTAIRS       0.99      1.00      0.99       206
#   WALKING_UPSTAIRS       0.99      0.98      0.99       200
#
#           accuracy                           0.98      1471
#          macro avg       0.98      0.98      0.98      1471
#       weighted avg       0.98      0.98      0.98      1471

# %%
lgr_clf_rs.best_estimator_
# Out:
# LogisticRegression(C=10)

# %%
#  Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8))
matrix = plot_confusion_matrix(lgr_clf_rs, X_test, Y_test,
                                 cmap='tab20b',display_labels=None,
                                 normalize='true',ax=ax)

fig.tight_layout()
plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':'15'} 
plt.title('Confusion matrix for Logistic Regression ',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show(matrix)

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the Logistic Regression, well-known exceptions include the classification of SITTING and WALKING_DOWNSTAIRS. Whereas LAYING, WALKING_UPSTAIRS, WALKING, and STANDING seemed to fail us sometimes as well.

# %%
train_model_score=train_model_score.append(pd.DataFrame({'Model':["LogisticRegression"],'Score':[train_lgr_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["LogisticRegression"],'Score':[test_lgr_accuracy]}))

# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# Random Forest Classifier is an ensemble algorithm. In the next one or two posts, we shall explore such algorithms. Ensembled algorithms combine more than one algorithms of the same or different kinds for classifying objects.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
# fit the model with the training data
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
# number of trees used
print('Number of Trees used : ', rfc.n_estimators)
# Out:
# Number of Trees used :  100

# %%
y_pred = rfc.predict(X_test)
X_pred = rfc.predict(X_train)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_rfc_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using Logisitc Regression:", test_rfc_accuracy)
# Out:
# Testing Accuracy using Logisitc Regression: 0.9775662814411965

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 98% while accurately analyzing the predicted output list.

# %% [markdown]
# # Checking the model's training accuracy

# %%
# Checking the model's training accuracy
train_rfc_accuracy=accuracy_score(Y_train,x_pred)
print("Testing Accuracy using Logisitc Regression:", train_rfc_accuracy)
# Out:
# Testing Accuracy using Logisitc Regression: 0.9916680836592416

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 99% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       280
#            SITTING       0.96      0.95      0.95       262
#           STANDING       0.95      0.96      0.96       276
#            WALKING       1.00      0.99      0.99       247
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       206
#   WALKING_UPSTAIRS       0.97      0.99      0.98       200
#
#           accuracy                           0.98      1471
#          macro avg       0.98      0.98      0.98      1471
#       weighted avg       0.98      0.98      0.98      1471

# %%
# Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8))
matrix = plot_confusion_matrix(rfc, X_test, Y_test,
                                 cmap='copper',
                                 normalize='true',ax=ax)

fig.tight_layout()
plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':'15'} 
plt.title('Confusion matrix for Random Forest ',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show(matrix)

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the Random Forest classifier, well-known exceptions include the classification of SITTING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS. Whereas LAYING, WALKING, and STANDING are seemed to fail us sometimes as well.

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["Random Forest"],'Score':[train_rfc_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["Random Forest"],'Score':[test_rfc_accuracy]}))

# %% [markdown]
# # Linear Discriminant Analysis

# %% [markdown]
# Linear Discriminant Analysis (LDA) is a dimensionality reduction technique. As the name implies, dimensionality reduction techniques reduce the number of dimensions (i.e., variables) in a dataset while retaining as much information as possible.

# %%
# define model
lda= LinearDiscriminantAnalysis()
# fit model
lda.fit(X_train,Y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
x_pred = lda.predict(X_train)
y_pred = lda.predict(X_test)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_lda_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using Linear Discriminant Analysis:",test_lda_accuracy)
# Out:
# Testing Accuracy using Linear Discriminant Analysis: 0.9775662814411965

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 97.7% while accurately analyzing the predicted output list.

# %% [markdown]
# # Checking the model's training accuracy

# %%
# Checking the model's testing accuracy
train_lda_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using Linear Discriminant Analysis:", train_lda_accuracy)
# Out:
# Training Accuracy using Linear Discriminant Analysis: 0.9867369494983846

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 98% while accurately analyzing the predicted output list.

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the Linear Discriminant Analysis, well-known exceptions include the classification of SITTING. Whereas LAYING, WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS, and STANDING are seemed to fail us sometimes as well.

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["Linear Discriminant Analysis"],
                                                           'Score':[train_lda_accuracy]}))

# %%
Test_model_score = test_model_score.append(pd.DataFrame({'Model':["Linear Discriminant Analysis"],
                                                    'Score':[test_lda_accuracy]}))

# %% [markdown]
# # K-Neighbors Classifier

# %% [markdown]
# The general idea behind K-nearest neighbors (KNN) is that data points are estimated to belong to the class with which it participates the most number of common points in terms of its distance. K number of nearest points nearby the data point to be predicted is taken into consideration. These K points at this time already refer to a class.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
min_max=MinMaxScaler()

# %%
my_odd_scaler = preprocessing.MinMaxScaler(feature_range=(-3.14,3.14))

# %%
# Fitting k-NN on our scaled data set
knn1=KNeighborsClassifier(n_neighbors=5,metric='minkowski', p=2)
knn1.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn1.predict(X_test)
x_pred = knn1.predict(X_train)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_knn1_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using K-Nearest Neighbor:", test_knn1_accuracy)
# Out:
# Testing Accuracy using K-Nearest Neighbor: 0.9639700883752549

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 96% while accurately analyzing the predicted output list.

# %% [markdown]
# # Checking the model's training accuracy

# %%
# Checking the model's training accuracy
train_knn1_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using K-Nearest Neighbor:", train_knn1_accuracy)
# Out:
# Training Accuracy using K-Nearest Neighbor: 0.980105424247577

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 98% while accurately analyzing the predicted output list.

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_test,y_pred)
pd.crosstab(Y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# Predicted           LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# Actual
# LAYING                 280        0         0        0                   0
# SITTING                  0      230        32        0                   0
# STANDING                 0       15       261        0                   0
# WALKING                  0        0         0      246                   0
# WALKING_DOWNSTAIRS       0        0         0        3                 202
# WALKING_UPSTAIRS         0        0         0        1                   0
# All                    280      245       293      250                 202
#
# Predicted           WALKING_UPSTAIRS   All
# Actual
# LAYING                             0   280
# SITTING                            0   262
# STANDING                           0   276
# WALKING                            1   247
# WALKING_DOWNSTAIRS                 1   206
# WALKING_UPSTAIRS                 199   200
# All                              201  1471

# %% [markdown]
# Conculsion
#
# Most often, our model gets wrong for SITTING and WALKING_DOWNSTAIRS cases.

# %%
with sns.axes_style('whitegrid'):
    k_range = range(1, 20)
    scores = []
    for k in k_range:
        knn = KNeighborsClassifier(n_neighbors = k)
        knn.fit(X_train, Y_train)
        scores.append(knn.score(X_test, Y_test))
    plt.figure()
    plt.figure(figsize=(20,5))
    plt.xlabel('k')
    plt.ylabel('accuracy')
    plt.plot(k_range, scores,'-o')
    plt.xticks([0,5,10,15,20])

# %% [markdown]
# Conculsion
#
# For this particular dataset, we obtain the highest accuracy when k=11 and 14.

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       280
#            SITTING       0.94      0.88      0.91       262
#           STANDING       0.89      0.95      0.92       276
#            WALKING       0.98      1.00      0.99       247
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       206
#   WALKING_UPSTAIRS       0.99      0.99      0.99       200
#
#           accuracy                           0.96      1471
#          macro avg       0.97      0.97      0.97      1471
#       weighted avg       0.96      0.96      0.96      1471

# %%
# Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8))
matrix = plot_confusion_matrix(knn1, X_test, Y_test,
                                 cmap='Blues',
                                normalize='true',ax=ax)

fig.tight_layout()
plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':15}
plt.title('Confusion matrix for K-Nearest Neighbor ',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show(matrix)

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the K-Nearest Neighbor, well-known exceptions include the classification of SITTING, WALKING_UPSTAIRS and WALKING_DOWNSTAIRS. Whereas LAYING, WALKING and STANDING are seemed to fail us sometimes as well.

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["K-Nearest Neighbor"],'Score':[train_knn1_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["K-Nearest Neighbor"],'Score':[test_knn1_accuracy]}))

# %% [markdown]
# # Gaussian Naive Bayes

# %% [markdown]
# Given the probability of certain related values, the formula to calculate the probability of an event B, given event A to occur is calculated as follows.
#
# P(B|A) = (P(A|B) * P(B) / P(A))
#
#
# This theory is considered naive, because it assumes that there is no dependency between any of the input features.

# %%
from sklearn.naive_bayes import GaussianNB

# %%
#Create a Gaussian Classifier
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
#Predict the response for test dataset
y_pred = gnb.predict(X_test)

#Predict the response for train dataset
x_pred = gnb.predict(X_train)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
test_gnb_accuracy=metrics.accuracy_score(Y_test, y_pred)
# Model Accuracy, how often is the classifier correct?
print("Testing Accuracy using Gaussian Naive Bayes :",test_gnb_accuracy)
# Out:
# Testing Accuracy using Gaussian Naive Bayes : 0.7307953772943576

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 73% while accurately analyzing the predicted output list.

# %% [markdown]
# # Checking the model's training accuracy

# %%
train_gnb_accuracy=metrics.accuracy_score(Y_train, x_pred)
# Model Accuracy, how often is the classifier correct?
print("Training Accuracy using Gaussian Naive Bayes :",train_gnb_accuracy)
# Out:
# Training Accuracy using Gaussian Naive Bayes : 0.7369494983846284

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 74% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       0.96      0.41      0.58       280
#            SITTING       0.51      0.73      0.60       262
#           STANDING       0.80      0.89      0.84       276
#            WALKING       0.93      0.74      0.82       247
# WALKING_DOWNSTAIRS       0.83      0.76      0.79       206
#   WALKING_UPSTAIRS       0.65      0.91      0.76       200
#
#           accuracy                           0.73      1471
#          macro avg       0.78      0.74      0.73      1471
#       weighted avg       0.78      0.73      0.73      1471

# %%
# Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8))

matrix = plot_confusion_matrix(gnb, X_test, Y_test,
                                 cmap="Oranges",
                                 normalize='true',ax=ax)

fig.tight_layout()
plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':15}
plt.title('Confusion matrix for GaussianNB ',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the GaussianNB, well-known exceptions include the classification of SITTING, LAYING and WALKING_DOWNSTAIRS. Whereas WALKING_UPSTAIRS, WALKING and STANDING are seemed to fail us sometimes as well.

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["GaussianNB"],'Score':[train_gnb_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["GaussianNB"],'Score':[test_gnb_accuracy]}))

# %% [markdown]
# # AdaBoost Classifier

# %% [markdown]
# AdaBoost algorithm, short for Adaptive Boosting, is a Boosting technique used as an Ensemble Method in Machine Learning. Adaptive Boosting as the weights are re-assigned to each instance, with higher weights to incorrectly classified models.

# %%
AB=AdaBoostClassifier()
#Train the model using the training sets
AB.fit(X_train, Y_train)
# Out:
# AdaBoostClassifier()

# %%
#Predict the response for test dataset
y_pred = AB.predict(X_test)
#Predict the response for train dataset
x_pred = AB.predict(X_train)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_AB_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using Ada Boost Classifier():", test_AB_accuracy)
# Out:
# Testing Accuracy using Ada Boost Classifier(): 0.5458871515975526

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 54.6% while accurately analyzing the predicted output list.

# %%
train_AB_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using Ada Boost Classifier():", train_AB_accuracy)
# Out:
# Training Accuracy using Ada Boost Classifier(): 0.5448053052202007

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 54.5% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       280
#            SITTING       0.00      0.00      0.00       262
#           STANDING       0.51      1.00      0.68       276
#            WALKING       0.38      1.00      0.55       247
# WALKING_DOWNSTAIRS       0.00      0.00      0.00       206
#   WALKING_UPSTAIRS       0.00      0.00      0.00       200
#
#           accuracy                           0.55      1471
#          macro avg       0.32      0.50      0.37      1471
#       weighted avg       0.35      0.55      0.41      1471

# %%
# Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8)) 
matrix = plot_confusion_matrix(AB, X_test, Y_test,
                                 cmap='tab20c_r', 
                               normalize='true',
                               ax=ax)

fig.tight_layout()
plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':15}
plt.title('Confusion matrix for Ada Boost Classifier ',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the Ada Boost Classifier, most often, our model gets wrong for all Activities cases.

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["Ada Boost Classifier"],'Score':[train_AB_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["Ada Boost Classifier"],'Score':[test_AB_accuracy]}))

# %% [markdown]
# # OneVsRestClassifier

# %% [markdown]
# OneVsRestClassifier - when we want to do multiclass or multilabel classification, and its strategy consists of fitting one classifier per class. For each classifier, the class is held against all the other classes

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn import svm

# %%
orc = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True, random_state=0))
orc.fit(X_train, Y_train)
# Out:
# OneVsRestClassifier(estimator=SVC(kernel='linear', probability=True,
#                                   random_state=0))

# %%
y_pred = orc.predict(X_test)
x_pred = orc.predict(X_train)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_orc_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using OneVsRestClassifier:", test_orc_accuracy)
# Out:
# Testing Accuracy using OneVsRestClassifier: 0.9857239972807614

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 98.6% while accurately analyzing the predicted output list.

# %% [markdown]
# # Checking the model's training accuracy

# %%
train_orc_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using OneVsRestClassifier:", train_orc_accuracy)
# Out:
# Training Accuracy using OneVsRestClassifier: 0.9931984356401973

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 99% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       280
#            SITTING       0.97      0.97      0.97       262
#           STANDING       0.97      0.97      0.97       276
#            WALKING       1.00      0.99      1.00       247
# WALKING_DOWNSTAIRS       1.00      1.00      1.00       206
#   WALKING_UPSTAIRS       0.99      0.99      0.99       200
#
#           accuracy                           0.99      1471
#          macro avg       0.99      0.99      0.99      1471
#       weighted avg       0.99      0.99      0.99      1471

# %%
# Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8)) 
matrix = plot_confusion_matrix(orc, X_test, Y_test,
                                 cmap='GnBu_r', 
                               normalize='true',
                               ax=ax)

fig.tight_layout()
plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':15} 
plt.title('Confusion matrix for OneVsRestClassifier ',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix, well-known exceptions include the classification of SITTING, LAYING and WALKING_DOWNSTAIRS. Whereas WALKING_UPSTAIRS, WALKING and STANDING are seemed to fail us sometimes as well.

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["OneVsRestClassifier"],
                                                     'Score':[train_orc_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["OneVsRestClassifier"],
                                                    'Score':[test_orc_accuracy]}))

# %% [markdown]
# # Variance Threshold

# %% [markdown]
# VarianceThreshold is a simple baseline approach to feature selection. It removes all features whose variance doesn’t meet some threshold. By default, it removes all zero-variance features, i.e., features with the same value in all samples.

# %%
from sklearn.feature_selection import VarianceThreshold
# Create VarianceThreshold object with a variance with a threshold of 0.5
VTH = VarianceThreshold(threshold=.5)

# Conduct variance thresholding
X_high_variance = VTH.fit_transform(X_train)

# %%
X_high_variance[0:5]
# Out:
# array([[-0.55511751, -0.81590899, -0.94635692, -1.        , -1.        ],
#        [-0.77895525,  0.56749301,  0.31660023,  0.27754216,  0.4866052 ],
#        [-0.25617624,  0.74787822,  0.66860558,  0.66259535,  0.40027441],
#        [ 0.88272434, -0.61974353, -0.72933706, -0.94369895, -0.93912029],
#        [ 0.99381435, -0.83558682, -1.        , -1.        , -1.        ]])

# %% [markdown]
# View the first five series with unique features with variances above the threshold.

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder, LabelEncoder
from sklearn.decomposition import PCA, IncrementalPCA
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # Pipeline

# %% [markdown]
# Machine learning (ML) pipelines consist of several steps to train a model. Machine learning pipelines are iterative as every effort is repeated to continuously improve the model's accuracy and achieve a successful algorithm. To build better machine learning models and get the most value from them, accessible, scalable, and durable storage solutions are imperative, paving the way for on-premises object storage.

# %%
pipe_lr = make_pipeline(StandardScaler(),
                        PCA(n_components=2),
                        LogisticRegression(random_state=1))
pipe_lr.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=2)),
#                 ('logisticregression', LogisticRegression(random_state=1))])

# %%
y_pred = pipe_lr.predict(X_test)
x_pred = pipe_lr.predict(X_train)

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_pipe_lr_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using Pipeline:", test_pipe_lr_accuracy)
# Out:
# Testing Accuracy using Pipeline: 0.5479265805574439

# %% [markdown]
# Conclusion
#
# We recognize that the model's testing accuracy efficiently is at 54.7% while accurately analyzing the predicted output list.

# %% [markdown]
# # Checking the model's training accuracy

# %%
train_pipe_lr_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using Pipeline:", train_pipe_lr_accuracy)
# Out:
# Training Accuracy using Pipeline: 0.5425947968032647

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 54.2% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test,y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       0.39      0.72      0.50       280
#            SITTING       0.00      0.00      0.00       262
#           STANDING       0.44      0.47      0.46       276
#            WALKING       0.77      0.80      0.78       247
# WALKING_DOWNSTAIRS       0.68      0.57      0.62       206
#   WALKING_UPSTAIRS       0.71      0.80      0.75       200
#
#           accuracy                           0.55      1471
#          macro avg       0.50      0.56      0.52      1471
#       weighted avg       0.48      0.55      0.50      1471

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["Pipeline"],
                                                     'Score':[train_pipe_lr_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["Pipeline"],
                                                    'Score':[test_pipe_lr_accuracy]}))

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator=pipe_lr,
                             X=X_train,
                             y=Y_train,
                             cv=10,
                             n_jobs=1)
print('CV accuracy scores:\n %s' % scores)
# Out:
# CV accuracy scores:
#  [0.54159593 0.54761905 0.55102041 0.53741497 0.5170068  0.54591837
#  0.53911565 0.54591837 0.53911565 0.53741497]

# %% [markdown]
# Conclusion
#
# By default, the score computed at each CV iteration is the scoring method of the estimator.

# %% [markdown]
# # Learning curves

# %% [markdown]
# A learning curve is a plot of model learning performance over experience or time.
#
# Learning curves are a widely used diagnostic tool in machine learning for algorithms that learn from a training dataset incrementally. The model can be evaluated on the training dataset and a holdout validation dataset after each update during training. We can create plots of the measured performance to show learning curves.

# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import learning_curve

pipe_lr = make_pipeline(StandardScaler(),
                        LogisticRegression(penalty='l2',
                                           random_state=1))

train_sizes, train_scores, test_scores =\
learning_curve(estimator=pipe_lr,
    X=X_train,
    y=Y_train,
    train_sizes=np.linspace(0.1, 1.0, 10),
    cv=10,
    n_jobs=1)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
plt.plot(train_sizes, train_mean,
         color='orchid', 
         marker='o',
        markersize=1, 
         label='train')

plt.fill_between(train_sizes,
                 train_mean + train_std,
                 train_mean - train_std, 
                  color='orchid')

plt.plot(train_sizes, test_mean,
         color='midnightblue', 
         marker='x', markersize=1,
         label='test')

plt.fill_between(train_sizes,
                 test_mean + test_std,
                 test_mean - test_std,
                 alpha=0.15, color='midnightblue')

plt.grid(True)
plt.xlabel('Number of training samples', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.title('Learning curves for a Logistic Regression model', fontsize = 18, y = 1.03)
plt.legend(loc="best",shadow=False, scatterpoints=1)
plt.ylim([0.75, 1.10])
plt.show()

# %% [markdown]
# Conclusion
#
# Compared to the theory we covered, our y-axis is 'score,' not 'error,' so the higher the score, the better the model's performance.
#
# Training score (pink line) decreases and plateau
#     * Indicates underfitting
#     * High bias
#
# Testing score (blue line) rotting throughout
#     * Unable to learn from data

# %% [markdown]
# # SGDClassifier

# %% [markdown]
# Stochastic Gradient Descent (SGD) is a simple yet very efficient approach to fitting linear classifiers and regressors under convex loss functions such as (linear) Support Vector Machines and Logistic Regression. Even though SGD has been around in the machine learning community for a long time, it has received a considerable amount of attention just recently in the context of large-scale learning.

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, Y_train)
# Out:
# SGDClassifier(random_state=42)

# %%
y_pred=sgd_clf.predict(X_test)
x_pred=sgd_clf.predict(X_train)

# %% [markdown]
# The coef_ member to a scipy. sparse matrix, which for L1-regularized models can be much more memory- and storage-efficient than the usual numpy.ndarray representation.

# %%
sgd_clf.coef_
# Out:
# array([[-3.56272640e-01, -4.41541499e-03,  2.42518752e-01, ...,
#          8.99287906e+00, -2.57860989e+00, -6.34931666e-01],
#        [-3.66365021e-01,  2.70904849e-01, -3.98300363e-01, ...,
#         -7.53486912e+00, -7.25115804e+00, -1.16007162e+00],
#        [ 3.69757840e-01,  1.59959197e-01,  4.51395505e-01, ...,
#         -4.27151960e+00,  9.05293793e+00,  9.01464884e-01],
#        [-4.89286509e-01, -1.49061077e-02,  1.54231652e-01, ...,
#         -1.54834830e+00, -4.80419500e-01,  4.66058804e-01],
#        [ 2.27339561e+00,  4.95024078e-01,  7.97824005e-01, ...,
#         -2.93530019e+00, -1.24238880e+00, -1.12133033e-01],
#        [-1.14825873e+00, -1.10583322e+00, -1.35948394e+00, ...,
#          1.33652168e+00,  2.51267134e+00,  1.47429036e+00]])

# %% [markdown]
# The intercept_ attribute holds the intercept (aka offset or bias)

# %%
sgd_clf.intercept_
# Out:
# array([ -9.06622842, -40.09643357, -44.88598755, -35.29951791,
#        -12.01449979, -45.57612524])

# %% [markdown]
# Conclusion
#
# The resulting value you see should be -9.16194034, -39.03137893, -45.36095594, -31.59229152, -9.53190555, -51.29282276

# %% [markdown]
# # Checking the model's testing accuracy

# %%
test_sgd_clf_accuracy=accuracy_score(Y_test,y_pred)
print("Testing Accuracy using  SGDClassifier:", test_sgd_clf_accuracy)
# Out:
# Testing Accuracy using  SGDClassifier: 0.9809653297076818

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 98% while accurately analyzing the predicted output list.

# %% [markdown]
# # Checking the model's training accuracy

# %%
train_sgd_clf_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using  SGDClassifier:", train_sgd_clf_accuracy)
# Out:
# Training Accuracy using  SGDClassifier: 0.9909879272232613

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 99% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       280
#            SITTING       0.95      0.97      0.96       262
#           STANDING       0.97      0.95      0.96       276
#            WALKING       1.00      1.00      1.00       247
# WALKING_DOWNSTAIRS       0.98      1.00      0.99       206
#   WALKING_UPSTAIRS       0.99      0.97      0.98       200
#
#           accuracy                           0.98      1471
#          macro avg       0.98      0.98      0.98      1471
#       weighted avg       0.98      0.98      0.98      1471

# %%
# Generate confusion matrix
fig, ax = plt.subplots(figsize=(12,8)) 
matrix = plot_confusion_matrix(sgd_clf, X_test, Y_test,
                                 cmap='BuGn', 
                               normalize='true',
                               ax=ax)

fig.tight_layout()
plt.rcParams.update({'font.size': 16})
plt.xlim(-0.5, len(np.unique(Y_train))-0.5)
plt.ylim(len(np.unique(Y_train))-0.5, -0.5)
label_font = {'size':15}
plt.title('Confusion matrix for SGD Classifier',fontdict=label_font)
ax.set_xlabel('Predicted labels', fontdict=label_font);
ax.set_ylabel('True labels', fontdict=label_font);
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Conclusion
#
# As a result, in the confusion matrix of the SGD Classifier, well-known exceptions include the classification of SITTING and STANDING. Whereas WALKING_UPSTAIRS,LAYING, WALKING_DOWNSTAIRS, WALKING are seemed to fail us sometimes as well.

# %%
train_model_score = train_model_score.append(pd.DataFrame({'Model':["SGD Classifier"],
                                                     'Score':[train_pipe_lr_accuracy]}))

# %%
test_model_score = test_model_score.append(pd.DataFrame({'Model':["SGD Classifier"],
                                                    'Score':[test_pipe_lr_accuracy]}))

# %%
le = LabelEncoder()
Y_train = le.fit_transform(Y_train)

le = LabelEncoder()
Y_test = le.fit_transform(Y_test)

# %%
le_name = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name)
# Out:
# {'LAYING': 0, 'SITTING': 1, 'STANDING': 2, 'WALKING': 3, 'WALKING_DOWNSTAIRS': 4, 'WALKING_UPSTAIRS': 5}

# %% [markdown]
# # Applying PCA

# %%
pca = PCA(50)

pca.fit(X_train)
pca.fit(X_test)
# Out:
# PCA(n_components=50)

# %%
train_x_pca = pca.transform(X_train)
test_x_pca = pca.transform(X_test)

# %% [markdown]
# The fit learns some quantities from the data, most importantly the "components" and "explained variance"

# %%
print(pca.n_components_)
print(pca.explained_variance_)
# Out:
# 50
# [35.22112343  2.84486052  2.20852607  1.05577942  0.93216131  0.71717364
#   0.68519854  0.59056802  0.53673124  0.48100038  0.4213355   0.40437497
#   0.34420838  0.30277069  0.29052987  0.27778287  0.25751593  0.24340005
#   0.23269124  0.23112339  0.21729537  0.20754204  0.19929849  0.19181624
#   0.18441429  0.18174997  0.17644043  0.16779748  0.16548492  0.16055886
#   0.15744435  0.15064344  0.14224191  0.13807788  0.13239719  0.12817799
#   0.12600065  0.12111307  0.11178542  0.10767043  0.10756573  0.10494498
#   0.10091486  0.09693789  0.09359034  0.09305535  0.09194735  0.08846574
#   0.08615842  0.08148839]

# %%
lgr_pca = LogisticRegression(penalty='l2',solver='lbfgs',class_weight='balanced', max_iter=10000,random_state = 0) 
lgr_pca.fit(train_x_pca, Y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=10000, random_state=0)

# %%
y_pred = lgr_pca.predict(test_x_pca)
x_pred = lgr_pca.predict(train_x_pca)

# %%
train_lgrpca_accuracy=accuracy_score(Y_train,x_pred)
print("Training Accuracy using Logistic Regression with PCA:", train_lgrpca_accuracy)
# Out:
# Training Accuracy using Logistic Regression with PCA: 0.9670124128549566

# %% [markdown]
# Conclusion
#
# We recognize that the model's training accuracy efficiently is at 96.7% while accurately analyzing the predicted output list.

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       280
#            1       0.92      0.88      0.90       262
#            2       0.89      0.93      0.91       276
#            3       0.98      0.99      0.98       247
#            4       0.98      0.99      0.98       206
#            5       0.98      0.96      0.97       200
#
#     accuracy                           0.96      1471
#    macro avg       0.96      0.96      0.96      1471
# weighted avg       0.96      0.96      0.96      1471

# %%
pca = PCA().fit(train_x_pca)
with sns.axes_style('whitegrid'):
    plt.plot(np.cumsum(pca.explained_variance_ratio_))
    plt.xlabel('number of components')
    plt.ylabel('cumulative explained variance');

# %%
pca = PCA(random_state=123)
pca.fit(X_train)
features = range(pca.n_components_)
with sns.axes_style('whitegrid'):
    plt.figure(figsize=(8,4))
    plt.bar(features[:15], pca.explained_variance_[:15], color='skyblue')
    plt.xlabel('PCA feature')
    plt.ylabel('Variance')
    plt.xticks(features[:15])
    plt.show()

# %% [markdown]
# # Incremental principal component analysis (IPCA)

# %% [markdown]
# Incremental principal component analysis (IPCA) is typically used as a replacement for principal component analysis (PCA) when the dataset to be decomposed too large to fit in memory. IPCA builds a low-rank approximation for the input data using an amount of memory independent of the number of input data samples. It is still dependent on the input data features, but changing the batch size allows for control of memory usage.

# %%
n_components = 10
ipca = IncrementalPCA(n_components=n_components, batch_size=10)
X_ipca = ipca.fit_transform(X_train)

pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_train)

colors = ['navy', 'green', 'orange']

for X_transformed, title in [(X_ipca, "Incremental PCA"), (X_pca, "PCA")]:
    plt.figure(figsize=(8, 8))
    for color, i, target_name in zip(colors, [0,1,2],labels):
        plt.scatter(X_transformed[Y_train == i, 0], X_transformed[Y_train == i, 1],
                    color=color, lw=6, label=target_name)

    if "Incremental" in title:
        err = np.abs(np.abs(X_pca) - np.abs(X_ipca)).mean()
        plt.title(title + " of HAR dataset\n\nMean absolute unsigned error "
                  "%.6f" % err)
    else:
        plt.title(title + " of HAR dataset")
    plt.legend(loc="best", shadow=False, scatterpoints=1)
    plt.axis([-8, 8, -7, 7])

plt.show()

# %% [markdown]
# Conclusion
#
# PCA works best on data set having three or higher dimensions. With higher dimensions, it becomes increasingly challenging to make interpretations from the resultant cloud of data.
#
# Mean absolute unsigned error 0.061737

# %% [markdown]
# # Training Accuracy Score To Evaluate Machine Learning Algorithms

# %%
train_model_score
# Out:
#                            Model     Score
# 0       Decision Tree Classifier  0.936065
# 0             LogisticRegression  0.991668
# 0                  Random Forest  0.991668
# 0   Linear Discriminant Analysis  0.986737
# 0             K-Nearest Neighbor  0.980105
# 0                     GaussianNB  0.736949
# 0           Ada Boost Classifier  0.544805
# 0            OneVsRestClassifier  0.993198
# 0                       Pipeline  0.542595
# 0                 SGD Classifier  0.542595
# 0  Logistic Regression using PCA  0.967012

# %% [markdown]
# # Testing Accuracy Score To Evaluate Machine Learning Algorithms

# %%
test_model_score
# Out:
#                       Model     Score
# 0  Decision Tree Classifier  0.921142
# 0        LogisticRegression  0.978246
# 0             Random Forest  0.977566
# 0        K-Nearest Neighbor  0.963970
# 0                GaussianNB  0.730795
# 0                GaussianNB  0.730795
# 0                GaussianNB  0.730795
# 0      Ada Boost Classifier  0.545887
# 0      Ada Boost Classifier  0.545887
# 0       OneVsRestClassifier  0.985724
# 0                  Pipeline  0.547927
# 0            SGD Classifier  0.547927
